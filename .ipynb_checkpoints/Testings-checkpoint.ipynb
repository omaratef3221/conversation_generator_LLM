# %%
#Chatting
from chatting import *

prompt = '''
generate a conversation between sam and nada about iphone 5
dialogue:
'''

print(generate_conversation(prompt, model='bloom'))
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[3], line 9
#       2 from chatting import *
#       4 prompt = '''
#       5 generate a conversation between sam and nada about iphone 5
#       6 dialogue:
#       7 '''
# ----> 9 print(generate_conversation(prompt, model='bloom'))
#
# File ~/Dropbox/Projects/AI/Conversation_Generator/chatting.py:38, in generate_conversation(text, model)
#      34 final_output_ft = tokenizer.decode(outputs_ft[0], skip_special_tokens=True)
#      35 ###############
#      36
#      37 ## Original model
# ...

# %%
tokenizer = AutoTokenizer.from_pretrained("Omaratef3221/bloom-560m-dialogue-generator")
model = AutoModelForCausalLM.from_pretrained("Omaratef3221/bloom-560m-dialogue-generator")

# %%
tokenizer(prompt, return_tensors = 'pt').input_ids
# Out:
# tensor([[   189,  82854,    267,  56462,   5299,  15209,    530,   9716,   3638,
#          217495,    973,    189,  65840,    672,     29,    189]])

# %%
xx = (model(tokenizer(prompt, return_tensors = 'pt').input_ids))

# %%
xx
# Out:
# CausalLMOutputWithCrossAttentions(loss=None, logits=tensor([[[  8.0817,   5.4995,  -1.7619,  ..., -14.6104, -14.6101, -14.6129],
#          [  6.5342,   5.7518,  -1.5927,  ..., -14.0362, -14.0358, -14.0387],
#          [  6.0344,   6.2655,  -1.9097,  ..., -13.6055, -13.6052, -13.6077],
#          ...,
#          [  5.8402,   7.5733,  -1.1869,  ..., -13.5172, -13.5167, -13.5192],
#          [  5.9921,   7.7188,  -1.5428,  ..., -13.0241, -13.0238, -13.0257],
#          [  6.0561,   7.8064,  -1.2989,  ..., -13.1334, -13.1330, -13.1351]]],
#        grad_fn=<UnsafeViewBackward0>), past_key_values=((tensor([[[ 1.7212e-01,  2.8329e-01, -2.7891e-01,  ..., -2.9709e-01,
#           -2.3052e-03,  1.7212e-01],
#          [-6.6290e-01,  1.3621e+00,  1.3286e+00,  ...,  6.8500e-01,
#           -3.5700e-01, -6.6290e-01],
#          [-9.2862e-01,  2.7303e-01,  5.7753e-01,  ..., -1.8785e-01,
#           -5.8582e-01, -9.2862e-01],
#          ...,
# ...

# %%
from transformers import pipeline

pipe = pipeline("text-generation", model="Omaratef3221/bloom-560m-dialogue-generator")

# %%
pipe(prompt)
# Out:
# /Users/omaratef/miniconda/lib/python3.10/site-packages/transformers/generation/utils.py:1273: UserWarning: Neither `max_length` nor `max_new_tokens` has been set, `max_length` will default to 20 (`generation_config.max_length`). Controlling `max_length` via the config is deprecated and `max_length` will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# [{'generated_text': '\ngenerate a conversation between sam and nada about iphone 5\ndialogue:\n####'}]

# %%
from dataset import *
from data_cleaning import *

data_obj = dataset("chatbot dataset.txt")
data = data_obj.read_df()
data = clean_data(data)
# Out:
# Metal device set to: Apple M2 Max
# 2023-02-27 20:03:16.850551: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2023-02-27 20:03:16.851061: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# All model checkpoint layers were used when initializing TFGPT2Model.
#
# All the layers of TFGPT2Model were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %%
data.head()
# Out:
#                          questions  \
# 0          what are your interests
# 1  what are your favorite subjects
# 2          what are your interests
# 3              what is your number
# 4              what is your number
#
#                                              answers
# 0  i am interested in all kinds of things we can ...
# 1  my favorite subjects include robotics computer...
# 2  i am interested in a wide variety of topics an...
# 3                            i dont have any number
# 4                                        23 skiddoo

# %%
model, tokenizer = get_model_tokenizer()
# Out:
# All model checkpoint layers were used when initializing TFGPT2Model.
#
# All the layers of TFGPT2Model were initialized from the model checkpoint at gpt2.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFGPT2Model for predictions without further training.

# %%
op = model(**tokenize_data(data["questions"][0]))

# %%
text = "Replace me by any text you'd like."
encoded_input = tokenizer(text, return_tensors='tf')
output = model(encoded_input)

# %%
output
# Out:
# TFBaseModelOutputWithPastAndCrossAttentions(last_hidden_state=<tf.Tensor: shape=(1, 10, 768), dtype=float32, numpy=
# array([[[ 0.1629054 , -0.2165744 , -0.14102806, ..., -0.26188618,
#          -0.08190899,  0.00923998],
#         [ 0.46279633,  0.02483842, -0.07853687, ..., -0.0858583 ,
#           0.51222336, -0.39390436],
#         [-0.06436808,  0.15511861, -0.6305841 , ...,  0.24878389,
#           0.3690539 ,  0.08326836],
#         ...,
#         [-0.5590811 , -0.4490239 , -1.4539903 , ...,  0.1649901 ,
#          -0.1302288 , -0.37402773],
#         [ 0.14001556, -0.3875274 , -0.79156214, ..., -0.17796883,
#           0.18236035,  0.21849123],
#         [ 0.1720702 , -0.24204722, -0.11238685, ..., -0.10684241,
#           0.12054697, -0.32129493]]], dtype=float32)>, past_key_values=(<tf.Tensor: shape=(2, 1, 12, 10, 64), dtype=float32, numpy=
# array([[[[[-1.07186699e+00,  2.41698933e+00,  9.66034830e-01, ...,
#            -4.78705883e-01, -3.31557035e-01,  1.79252338e+00],
# ...
